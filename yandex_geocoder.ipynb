# %%
import requests
import pandas as pd

# Ваш API-ключ Яндекс-геокодера
API_KEY = "xXxXxXxX-xXxX-4xxx-aXxX-2d6dc07cf70e"

# Файл Excel с адресами для геокодирования
excel_file = "source.xlsx"

# Чтение адресов из Excel-файла в pandas DataFrame
df = pd.read_excel(excel_file, sheet_name="График")

# Создание списка адресов для геокодирования
addresses = df["Адрес"].tolist()

# Список для хранения результатов геокодирования
results = []

# Отправка запроса к Яндекс-геокодеру для каждого адреса
for address in addresses:
    url = f"https://geocode-maps.yandex.ru/1.x/?apikey={API_KEY}&geocode={address}&format=json&results=1"
    response = requests.get(url)
    if response.status_code == 200:
        # Извлечение координат из ответа Яндекс-геокодера
        json_data = response.json()
        pos = json_data["response"]["GeoObjectCollection"]["featureMember"][0]["GeoObject"]["Point"]["pos"]
        lon, lat = map(float, pos.split())
        results.append((address, lat, lon))
    else:
        print(f"Ошибка при геокодировании адреса {address}: {response.status_code}")

# Сохранение результатов в новый Excel-файл
result_df = pd.DataFrame(results, columns=["Адрес", "Широта", "Долгота"])
result_df.to_excel("результаты.xlsx", index=False)

# %%
# !pip install geopandas
# Out:
# Requirement already satisfied: geopandas in /usr/local/lib/python3.10/dist-packages (0.13.2)
# Requirement already satisfied: fiona>=1.8.19 in /usr/local/lib/python3.10/dist-packages (from geopandas) (1.9.4.post1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from geopandas) (23.1)
# Requirement already satisfied: pandas>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from geopandas) (1.5.3)
# Requirement already satisfied: pyproj>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from geopandas) (3.6.0)
# Requirement already satisfied: shapely>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from geopandas) (2.0.1)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (23.1.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (2023.5.7)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (8.1.6)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (0.7.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (1.22.4)

# %%
import geopandas as gpd
import pandas as pd

# %%
# Чтение данных из Excel-файла
df = pd.read_excel("результаты.xlsx")

# Создание GeoDataFrame на основе данных из DataFrame
gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df["Долгота"], df["Широта"]), crs="EPSG:4326")

# Экспорт GeoDataFrame в GeoJSON файл
gdf.to_file("результаты.geojson", driver="GeoJSON")

# %%
import folium
import geopandas as gpd

# Чтение данных из GeoJSON файла
gdf = gpd.read_file("результаты.geojson")

# Создание интерактивной карты с помощью библиотеки folium
m = folium.Map(location=[gdf["Широта"].mean(), gdf["Долгота"].mean()], zoom_start=10)

# Добавление объектов на карту
for idx, row in gdf.iterrows():
    folium.Marker([row["Широта"], row["Долгота"]], tooltip=row["Адрес"]).add_to(m)

# Отображение карты
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d5d7ab8dc89463d59db29d7c9ce06067 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d5d7ab8dc89463d59db29d7c9ce06067&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d5d7ab8dc89463d59db29d7c9ce06067 = L.map(
#                 &quot;map_d5d7ab8dc89463d59db29d7c9ce06067&quot;,
#                 {
#                     center: [55.895379226837065, 37.449950827476044],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_70e3264ab8facb1e15284ce58e143039 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d5d7ab8dc89463d59db29d7c9ce06067);
#
#
#             var marker_d67e73923fcc6b11be0b26d8f73c6f18 = L.marker(
#                 [55.884105, 37.44868],
#                 {}
#             ).addTo(map_d5d7ab8dc89463d59db29d7c9ce06067);
#
#
#             marker_d67e73923fcc6b11be0b26d8f73c6f18.bindTooltip(
#                 `&lt;div&gt;
#                      Россия, Химки, ул.Зои Космодемьянской ул. д.1
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c85e43b33fa0dcba4d3c23f44dca542c = L.marker(
#                 [55.884186, 37.448024],
#                 {}
#             ).addTo(map_d5d7ab8dc89463d59db29d7c9ce06067);
#
#
#             marker_c85e43b33fa0dcba4d3c23f44dca542c.bindTooltip(
#                 `&lt;div&gt;
#                      Россия, Химки, ул.Зои Космодемьянской ул. д.3
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2cd139f591b7c8617c6116de84ed62c0 = L.marker(
#                 [55.88407, 37.451258],
#                 {}
#             ).addTo(map_d5d7ab8dc89463d59db29d7c9ce06067);
#
#
#             marker_2cd139f591b7c8617c6116de84ed62c0.bindTooltip(
#                 `&lt;div&gt;
#                      Россия, Химки, ул.Зои Космодемьянской ул. д.4
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_239d39202bf089f629c19fd07d9262b4 = L.marker(
#                 [55.88459, 37.451707],
#                 {}
#             ).addTo(map_d5d7ab8dc89463d59db29d7c9ce06067);
#
#
#             marker_239d39202bf089f629c19fd07d9262b4.bindTooltip(
#                 `&lt;div&gt;
#                      Россия, Химки, ул.Зои Космодемьянской ул. д.4а
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_bd8072a83a1a91e0a22a067dafff6e9e = L.marker(
#                 [55.8882, 37.445302],
#                 {}
#             ).addTo(map_d5d7ab8dc89463d59db29d7c9ce06067);
#
#
#             marker_bd8072a83a1a91e0a22a067dafff6e9e.bindTooltip(
#                 `&lt;div&gt;
#                      Россия, Химки, ул.Калинина ул. д.13
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_349b9d27c18df30e4be58f074b7b7373 = L.marker(
#                 [55.885428, 37.451752],
#                 {}
#             ).addTo(map_d5d7ab8dc89463d59db29d7c9ce06067);
#
#
#             marker_349b9d27c18df30e4be58f074b7b7373.bindTooltip(
#                 `&lt;div&gt;
#                      Россия, Химки, ул.Калинина ул. д.3
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f3ed6bdbce25f88c2312b6cfd9284799 = L.marker(
#                 [55.885201, 37.451007],
#                 {}
#             ).addTo(map_d5d7ab8dc89463d59db29d7c9ce06067);
#
#
#             marker_f3ed6bdbce25f88c2312b6cfd9284799.bindTooltip(
#                 `&lt;div&gt;
#                      Россия, Химки, ул.Калинина ул. д.3а
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a0188a32b4b58dbe3aca0eb9a44e472d = L.marker(
#                 [55.88462, 37.452426],
#                 {}
#             ).addTo(map_d5d7ab8dc89463d59db29d7c9ce06067);
#
#
#             marker_a0188a32b4b58dbe3aca0eb9a44e472d.bindTooltip(
#                 `&lt;div&gt;
#                      Россия, Химки, ул.Кирова ул. д.28
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_498109ec07d6f2a7fd3efbb4affcf28f = L.marker(
#                 [55.884166, 37.452723],
#                 {}
#             ).addTo(map_d5d7ab8dc89463d59db29d7c9ce06067);
#
#
#             marker_498109ec07d6f2a7fd3efbb4affcf28f.bindTooltip(
#                 `&lt;div&gt;
#                      Россия, Химки, ул.Кирова ул. д.30
#                  &lt;/div&gt;`,
